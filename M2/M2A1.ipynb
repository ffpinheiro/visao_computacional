# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/fabricio/.local/lib/python3.10/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /home/fabricio/.local/lib/python3.10/site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread("gato-maracaja.jpg")
# Out:
# [ WARN:0@1.996] global loadsave.cpp:278 findDecoder imread_('gato-maracaja.jpg'): can't open/read file: check file path/integrity

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
sift = cv2.SIFT_create()
keypoints, descriptors = sift.detectAndCompute(image, None)
image_kp = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(cv2.cvtColor(image_kp, cv2.COLOR_BGR2RGB))

# %%
orb = cv2.ORB_create(30)
keypoints, descriptors = orb.detectAndCompute(image,None)
image_kp = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(cv2.cvtColor(image_kp,cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 3
#       1 orb = cv2.ORB_create(30)
#       2 keypoints, descriptors = orb.detectAndCompute(image,None)
# ----> 3 image_kp = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#       4 plt.imshow(cv2.cvtColor(image_kp,cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
